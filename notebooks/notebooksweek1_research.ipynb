# %%
print("AI Fashion Design Assistant")
print("Week 1 Research Completed")

fashion_styles = [
    "Casual",
    "Formal",
    "Streetwear",
    "Vintage",
    "Luxury"
]

for style in fashion_styles:
    print(style)
# Out:
# AI Fashion Design Assistant
# Week 1 Research Completed
# Casual
# Formal
# Streetwear
# Vintage
# Luxury
